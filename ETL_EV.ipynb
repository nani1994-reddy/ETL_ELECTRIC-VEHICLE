# %%
import pandas as pd
import warnings
import numpy as  np

warnings.filterwarnings("ignore")
# Load the data from the uploaded file
data = pd.read_csv('.\Electric_Vehicle_Population_Data.csv')

# Preview the first few rows
data.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year     Make  \
# 0  5UXTA6C0XM     Kitsap    Seabeck    WA      98380.0        2021      BMW
# 1  5YJ3E1EB1J     Kitsap    Poulsbo    WA      98370.0        2018    TESLA
# 2  WP0AD2A73G  Snohomish    Bothell    WA      98012.0        2016  PORSCHE
# 3  5YJ3E1EB5J     Kitsap  Bremerton    WA      98310.0        2018    TESLA
# 4  1N4AZ1CP3K       King    Redmond    WA      98052.0        2019   NISSAN
#
#       Model                   Electric Vehicle Type  \
# 0        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1   MODEL 3          Battery Electric Vehicle (BEV)
# 2  PANAMERA  Plug-in Hybrid Electric Vehicle (PHEV)
# 3   MODEL 3          Battery Electric Vehicle (BEV)
# 4      LEAF          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            30.0
# ...

# %%
data
# Out:
#         VIN (1-10)     County              City State  Postal Code  \
# 0       5UXTA6C0XM     Kitsap           Seabeck    WA      98380.0
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 2       WP0AD2A73G  Snohomish           Bothell    WA      98012.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 4       1N4AZ1CP3K       King           Redmond    WA      98052.0
# ...            ...        ...               ...   ...          ...
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210161  JM3KKBHA0R     Kitsap         Bremerton    WA      98312.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
# 210163  5YJ3E1EA1M       King          Kirkland    WA      98034.0
# 210164  7SAYGDEE0P    Spokane           Spokane    WA      99208.0
#
#         Model Year     Make       Model  \
# 0             2021      BMW          X5
# 1             2018    TESLA     MODEL 3
# ...

# %%
data.shape
# Out:
# (210165, 17)

# %%
data.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# Base MSRP                                            float64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
data.isnull()
# Out:
#         VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0            False   False  False  False        False       False  False
# 1            False   False  False  False        False       False  False
# 2            False   False  False  False        False       False  False
# 3            False   False  False  False        False       False  False
# 4            False   False  False  False        False       False  False
# ...            ...     ...    ...    ...          ...         ...    ...
# 210160       False   False  False  False        False       False  False
# 210161       False   False  False  False        False       False  False
# 210162       False   False  False  False        False       False  False
# 210163       False   False  False  False        False       False  False
# 210164       False   False  False  False        False       False  False
#
#         Model  Electric Vehicle Type  \
# 0       False                  False
# ...

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         5
# Base MSRP                                              5
# Legislative District                                 445
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       4
# ...

# %%
data[["Model", "Model Year"]]
# Out:
#              Model  Model Year
# 0               X5        2021
# 1          MODEL 3        2018
# 2         PANAMERA        2016
# 3          MODEL 3        2018
# 4             LEAF        2019
# ...            ...         ...
# 210160        NIRO        2018
# 210161       CX-90        2024
# 210162  RAV4 PRIME        2023
# 210163     MODEL 3        2021
# 210164     MODEL Y        2023
#
# [210165 rows x 2 columns]

# %%
data["Model Year"].value_counts()
# Out:
# Model Year
# 2023    60071
# 2024    35237
# 2022    28258
# 2021    19813
# 2018    14295
# 2020    12135
# 2019    10754
# 2017     8593
# 2016     5452
# 2015     4722
# 2013     4307
# 2014     3457
# 2012     1549
# 2025      760
# 2011      704
# 2010       24
# 2008       22
# 2000        7
# 2002        2
# 1999        2
# 2003        1
# Name: count, dtype: int64

# %%
data["Model Year"].value_counts(ascending=False)
# Out:
# Model Year
# 2023    60071
# 2024    35237
# 2022    28258
# 2021    19813
# 2018    14295
# 2020    12135
# 2019    10754
# 2017     8593
# 2016     5452
# 2015     4722
# 2013     4307
# 2014     3457
# 2012     1549
# 2025      760
# 2011      704
# 2010       24
# 2008       22
# 2000        7
# 2002        2
# 1999        2
# 2003        1
# Name: count, dtype: int64

# %%
data["Model Year"].value_counts(ascending=True)
# Out:
# Model Year
# 2003        1
# 1999        2
# 2002        2
# 2000        7
# 2008       22
# 2010       24
# 2011      704
# 2025      760
# 2012     1549
# 2014     3457
# 2013     4307
# 2015     4722
# 2016     5452
# 2017     8593
# 2019    10754
# 2020    12135
# 2018    14295
# 2021    19813
# 2022    28258
# 2024    35237
# 2023    60071
# Name: count, dtype: int64

# %%
data["Model Year"].value_counts(ascending=True, normalize=True)
# Out:
# Model Year
# 2003    0.000005
# 1999    0.000010
# 2002    0.000010
# 2000    0.000033
# 2008    0.000105
# 2010    0.000114
# 2011    0.003350
# 2025    0.003616
# 2012    0.007370
# 2014    0.016449
# 2013    0.020493
# 2015    0.022468
# 2016    0.025942
# 2017    0.040887
# 2019    0.051169
# 2020    0.057740
# 2018    0.068018
# 2021    0.094274
# 2022    0.134456
# 2024    0.167664
# 2023    0.285828
# Name: proportion, dtype: float64

# %%
data["Model Year"].unique()
# Out:
# array([2021, 2018, 2016, 2019, 2015, 2020, 2017, 2024, 2012, 2022, 2023,
#        2025, 2013, 2011, 2014, 2008, 2010, 2000, 2002, 1999, 2003],
#       dtype=int64)

# %%
data["Model Year"].value_counts()
# Out:
# Model Year
# 2023    60071
# 2024    35237
# 2022    28258
# 2021    19813
# 2018    14295
# 2020    12135
# 2019    10754
# 2017     8593
# 2016     5452
# 2015     4722
# 2013     4307
# 2014     3457
# 2012     1549
# 2025      760
# 2011      704
# 2010       24
# 2008       22
# 2000        7
# 2002        2
# 1999        2
# 2003        1
# Name: count, dtype: int64

# %%
len(data["Model Year"].unique())
# Out:
# 21

# %%
data["Model Year"].nunique()
# Out:
# 21

# %%
data.query("`Model Year` == 2018").shape
# Out:
# (14295, 17)

# %%
data.query("(`Model Year` == 2018) and (`Electric Vehicle Type` == 'Plug-in Hybrid Electric Vehicle (PHEV)')").shape
# Out:
# (4377, 17)

# %%
data.query("(`Model Year` == 2018) and (`Make` == 'TOYOTA')").shape
# Out:
# (674, 17)

# %%
data.query("(`Model Year` == 2018) and (`Make` == 'TOYOTA')")
# Out:
#         VIN (1-10)        County      City State  Postal Code  Model Year  \
# 442     JTDKARFP3J          King   Seattle    WA      98115.0        2018
# 891     JTDKARFP5J     Snohomish   Bothell    WA      98021.0        2018
# 1132    JTDKARFP2J          King   Seattle    WA      98125.0        2018
# 1536    JTDKARFP0J        Yakima    Yakima    WA      98902.0        2018
# 2496    JTDKARFP1J          King    Burien    WA      98146.0        2018
# ...            ...           ...       ...   ...          ...         ...
# 208847  JTDKARFP0J       Spokane   Spokane    WA      99205.0        2018
# 208958  JTDKARFP8J        Pierce    Graham    WA      98338.0        2018
# 209138  JTDKARFP6J          King   Seattle    WA      98178.0        2018
# 209496  JTDKARFPXJ          King  Kirkland    WA      98033.0        2018
# 209652  JTDKARFP3J  Grays Harbor  Mccleary    WA      98557.0        2018
#
#           Make        Model                   Electric Vehicle Type  \
# ...

# %%
data.query("(`Model Year` == 2018) or (`Make` == 'TOYOTA')")
# Out:
#         VIN (1-10)     County              City State  Postal Code  \
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 12      JTMAB3FV5R     Kitsap           Poulsbo    WA      98370.0
# 22      5YJ3E1EB1J       King          Issaquah    WA      98027.0
# 31      5YJXCAE2XJ  Snohomish           Bothell    WA      98021.0
# ...            ...        ...               ...   ...          ...
# 210127  JTDKARFP1H    Douglas    East Wenatchee    WA      98802.0
# 210129  5YJ3E1EB2J  Snohomish           Edmonds    WA      98020.0
# 210133  5YJXCDE23J     Pierce        Gig Harbor    WA      98335.0
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
#
#         Model Year    Make        Model  \
# 1             2018   TESLA      MODEL 3
# 3             2018   TESLA      MODEL 3
# ...

# %%
# Filter the data to include only rows where 'Model Year' is 2018 & where 'Make' is 'TOYOTA'
data.query("`Model Year` == 2018").query("`Make` == 'TOYOTA'")
#data.filter(col("Model Year")=2018) AND MAKE =To....

# # give me a list of cars produced per 2020 (all brands)
# df.groupBy(col('Make')).agg(count(field_name))

# select count(*) from tablename

# select count(cars) as car_count from table
# groupby make
# Out:
#         VIN (1-10)        County      City State  Postal Code  Model Year  \
# 442     JTDKARFP3J          King   Seattle    WA      98115.0        2018
# 891     JTDKARFP5J     Snohomish   Bothell    WA      98021.0        2018
# 1132    JTDKARFP2J          King   Seattle    WA      98125.0        2018
# 1536    JTDKARFP0J        Yakima    Yakima    WA      98902.0        2018
# 2496    JTDKARFP1J          King    Burien    WA      98146.0        2018
# ...            ...           ...       ...   ...          ...         ...
# 208847  JTDKARFP0J       Spokane   Spokane    WA      99205.0        2018
# 208958  JTDKARFP8J        Pierce    Graham    WA      98338.0        2018
# 209138  JTDKARFP6J          King   Seattle    WA      98178.0        2018
# 209496  JTDKARFPXJ          King  Kirkland    WA      98033.0        2018
# 209652  JTDKARFP3J  Grays Harbor  Mccleary    WA      98557.0        2018
#
#           Make        Model                   Electric Vehicle Type  \
# ...

# %%
grouped_data = data.groupby('Make').size().reset_index(name='count')
data

# %%
# Check for missing values in each column and sum them up
data.isnull().sum()

# %%
# Fill missing values with 'unknown'
data['County'].fillna('unknown', inplace=True)
data['City'].fillna('unknown', inplace=True)
data['Postal Code'].fillna('unknown', inplace=True)
data['Electric Range'].fillna('unknown', inplace=True)
data['Base MSRP'].fillna('unknown', inplace=True)
data['Vehicle Location'].fillna('unknown', inplace=True)
data

# %%
# Check for missing values in each column and sum them up
data.isnull().sum()

# %%
# Fill missing values with 'unknown'
data['Legislative District'].fillna('unknown', inplace=True)
data['Electric Utility'].fillna('unknown', inplace=True)
data['2020 Census Tract'].fillna('unknown', inplace=True)
data

# %%
# Check for missing values in each column and sum them up
data.isnull().sum()

# %%
data.dtypes

# %%
# String to Numeric: These columns are best converted to numeric types:
# Postal Code (to int)
# Electric Range (to int or float)
# Base MSRP (to float)
data['Postal Code'] = pd.to_numeric(data['Postal Code'], errors='coerce').astype('Int64')
data['Electric Range'] = pd.to_numeric(data['Electric Range'], errors='coerce')
data['Base MSRP'] = pd.to_numeric(data['Base MSRP'], errors='coerce')
data

# %%
# Display the data types of each column
data.dtypes

# %%
# Save the cleaned dataset to a new CSV file
data.to_csv('EVcleaned_data.csv', index=False)

# %%
# First, install the Google Cloud Storage client library if you haven't already
# !pip install google-cloud-storage

import os
from google.cloud import storage

# Set the path to your service account key
service_account_key_path = r'C:/Users/Personal/Miracle/ETL/project1-439615-7a1d4e03c029.json'

# blob.upload_from_filename(source_file_name, timeout=600)  # Timeout in seconds

blob = bucket.blob(destination_blob_name)
blob.chunk_size = 262144  # Set a chunk size (256 KB)
blob.upload_from_filename(source_file_name, timeout=600)  # Adjust timeout as needed




# Make sure the file path is correct
# if not os.path.exists(service_account_key_path):
#     raise FileNotFoundError(f"File {service_account_key_path} was not found.")

# Set the environment variable for the Google Cloud credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key_path

# Initialize a client
client = storage.Client()

# Specify the bucket name and the file to upload
bucket_name = 'evcars4321'
source_file_name = 'EVcleaned_data.csv'
destination_blob_name = 'EVfinal_data.csv'

# Get the bucket
bucket = client.get_bucket(bucket_name)

# Create a blob object for the file in the bucket
blob = bucket.blob(destination_blob_name)

# Upload the file to the bucket
blob.upload_from_filename(source_file_name)

print(f'File {source_file_name} uploaded to {bucket_name}/{destination_blob_name}.')

# %%
##aggregations
## regex
